# %%
# imports necessary libraries and functions from the 'useful_functions.py' file
from useful_functions import *
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\carson.witt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\carson.witt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# imports json file to a pandas dataframe line by line and skips the lines with improper json syntax
df = df_from_json('comment_code_data_very_small.json')
df.head()
# Out:
#                                                 body  \
# 0      public void execute(BatchParams batchParam...
# 1      public List<Integer> getDataList(BatchPara...
# 2       public Stack(){\n        head = null;\n    }
# 3  public DrawingPanel(){\n            super();\n...
# 4          public void addObject(DrawableObject d...
#
#                                              comment
# 0  /**\n     * 处理每一条记录\n     * <b>业务处理方法</b><br/>...
# 1  /**\n     * 分页处理\n     * @param batchParams\n ...
# 2  /* ---------------------- Ende der inneren Kla...
# 3           /**\n         * Konstruktor\n         */
# 4  /**\n         * Diese Methode fügt ein neues O...

# %%
# cleans each comment to just lowercase text and numbers (keeps '@')
clean_comments(df)
# Out:
#                                                      body  \
# 0           public void execute(BatchParams batchParam...
# 1           public List<Integer> getDataList(BatchPara...
# 2            public Stack(){\n        head = null;\n    }
# 3       public DrawingPanel(){\n            super();\n...
# 4               public void addObject(DrawableObject d...
# ...                                                   ...
# 499993    public double evaluatePotential(double x) {\...
# 499994    public void normalize() {\n    double dx = g...
# 499995    public double evaluatePotential(double x) {\...
# 499996    public double getDx() {\n    return xmax / (...
# 499997    public void getRate(double[] state, double[]...
#
#                                                   comment  \
# 0       /**\n     * 处理每一条记录\n     * <b>业务处理方法</b><br/>...
# 1       /**\n     * 分页处理\n     * @param batchParams\n ...
# 2       /* ---------------------- Ende der inneren Kla...
# 3                /**\n         * Konstruktor\n         */
# 4       /**\n         * Diese Methode fügt ein neues O...
# ...                                                   ...
# 499993  /**\n   * Evaluates the potential using a step...
# 499994   /**\n   * normalize the function in place\n   */
# 499995  /**\n   * Evaluates the potential using a step...
# 499996                           /**\n   * @return\n   */
# 499997  /**\n   * Gets the rate using the given state....
#
#                                                     clean
# 0        \n        \n        b b br \n        getdatal...
# 1        \n        \n       @param batchparams\n      ...
# 2                               ende der inneren klasse
# 3                    \n           konstruktor\n
# 4        \n           diese methode f gt ein neues obj...
# ...                                                   ...
# 499993   \n     evaluates the potential using a step a...
# 499994       \n     normalize the function in place\n
# 499995   \n     evaluates the potential using a step a...
# 499996                               \n     @return\n
# 499997   \n     gets the rate using the given state \n...
#
# [499998 rows x 3 columns]

# %%
# combines each comment into a singular list
combined_comments = " ".join(df['clean'])

# %%
# separates each word into individual tokens or objects
words = combined_comments.split()

# %%
# bow = bag of words
# ngrams is a nltk library that looks for occurances of n consecutive words in text

# counts number of occurances of each word in the combined comments, puts each word and its frequency into a dictionary
bow = Counter(words)

# same as above, but for pairs of words 
bow2 = Counter(ngrams(words,2))

# same as above, but for trigrams (3 words in a row)
bow3 = Counter(ngrams(words,3))

# %%
# run this if you want to see what the dictionary looks like
bow2
# Out:
# Counter({('b', 'b'): 241,
#          ('b', 'br'): 136,
#          ('br', 'getdatalist'): 3,
#          ('getdatalist', 'br'): 3,
#          ('br', 'datalist'): 12,
#          ('datalist', 'br'): 3,
#          ('datalist', 'stepservice'): 6,
#          ('stepservice', 'batch'): 3,
#          ('batch', 'step'): 3,
#          ('step', 'br'): 5,
#          ('stepservice', 'br'): 3,
#          ('datalist', 'size'): 3,
#          ('size', '1'): 475,
#          ('1', '@param'): 1145,
#          ('@param', 'index'): 2254,
#          ('index', 'data'): 23,
#          ('data', 'object'): 217,
#          ('object', '1'): 15,
#          ('@param', 'data'): 1951,
#          ('data', 'getdatalist'): 3,
#          ('getdatalist', '@param'): 3,
#          ('@param', 'object'): 1428,
#          ('object', 'getobjectlist'): 3,
#          ('getobjectlist', 'object'): 3,
#          ('object', '@param'): 2986,
#          ('@param', 'batchparams'): 3,
#          ('batchparams', '@param'): 3,
#          ('@param', 'offset'): 1096,
#          ('offset', '@param'): 411,
#          ('@param', 'pagesize'): 112,
#          ('pagesize', '@param'): 30,
#          ('object', '@return'): 2030,
#          ('@return', '@throws'): 2050,
#          ('@throws', 'batchexception'): 3,
#          ('batchexception', 'ende'): 3,
#          ('ende', 'der'): 4,
#          ('der', 'inneren'): 3,
#          ('inneren', 'klasse'): 3,
#          ('klasse', 'konstruktor'): 3,
#          ('konstruktor', 'diese'): 3,
#          ('diese', 'methode'): 17,
#          ('methode', 'f'): 6,
#          ('f', 'gt'): 11,
#          ('gt', 'ein'): 4,
#          ('ein', 'neues'): 19,
#          ('neues', 'objekt'): 15,
#          ('objekt', 'zum'): 3,
#          ('zum', 'zeichnen'): 3,
#          ('zeichnen', 'hinzu'): 3,
#          ('hinzu', 'die'): 3,
#          ('die', 'klasse'): 6,
#          ('klasse', 'des'): 6,
#          ('des', 'objekts'): 6,
#          ('objekts', 'muss'): 6,
#          ('muss', 'mindestens'): 6,
#          ('mindestens', 'das'): 6,
#          ('das', 'interface'): 6,
#          ('interface', 'drawableobject'): 6,
#          ('drawableobject', 'implementieren'): 6,
#          ('implementieren', '@param'): 6,
#          ('@param', 'd'): 535,
#          ('d', 'das'): 6,
#          ('das', 'ab'): 6,
#          ('ab', 'sofort'): 6,
#          ('sofort', 'zu'): 3,
#          ('zu', 'zeichnende'): 6,
#          ('zeichnende', 'objekt'): 6,
#          ('objekt', 'diese'): 3,
#          ('methode', 'entfernt'): 3,
#          ('entfernt', 'ein'): 3,
#          ('ein', 'objekt'): 3,
#          ('objekt', 'aus'): 6,
#          ('aus', 'der'): 17,
#          ('der', 'menge'): 3,
#          ('menge', 'der'): 3,
#          ('der', 'zu'): 8,
#          ('zu', 'zeichnenden'): 3,
#          ('zeichnenden', 'objekte'): 3,
#          ('objekte', 'die'): 3,
#          ('sofort', 'nicht'): 3,
#          ('nicht', 'mehr'): 9,
#          ('mehr', 'zu'): 3,
#          ('objekt', 'unbenutzt'): 3,
#          ('unbenutzt', 'bis'): 15,
#          ('bis', 'auf'): 15,
#          ('auf', 'weiteres'): 15,
#          ('weiteres', 'weitergabe'): 6,
#          ('weitergabe', 'an'): 9,
#          ('an', 'zeichnungsobjekte'): 9,
#          ('zeichnungsobjekte', 'weitergabe'): 3,
#          ('zeichnungsobjekte', 'unbenutzt'): 3,
#          ('weiteres', 'unbenutzt'): 9,
#          ('zeichnungsobjekte', 'konstruktor'): 3,
#          ('konstruktor', '@param'): 9,
#          ('@param', 'name'): 5144,
#          ('name', 'der'): 4,
#          ('der', 'titel'): 3,
#          ('titel', 'des'): 3,
#          ('des', 'fensters'): 15,
#          ('fensters', '@param'): 6,
#          ('@param', 'x'): 2817,
#          ('x', 'die'): 3,
#          ('die', 'obere'): 6,
#          ('obere', 'linke'): 6,
#          ('linke', 'x'): 3,
#          ('x', 'koordinate'): 3,
#          ('koordinate', 'des'): 3,
#          ('fensters', 'bzgl'): 6,
#          ('bzgl', 'des'): 6,
#          ('des', 'bildschirms'): 6,
#          ('bildschirms', '@param'): 6,
#          ('@param', 'y'): 2242,
#          ('y', 'die'): 4,
#          ('linke', 'y'): 3,
#          ('y', 'koordinaite'): 3,
#          ('koordinaite', 'des'): 3,
#          ('@param', 'width'): 1257,
#          ('width', 'die'): 3,
#          ('die', 'breite'): 3,
#          ('breite', 'des'): 3,
#          ('@param', 'height'): 1137,
#          ('height', 'die'): 3,
#          ('die', 'h'): 4,
#          ('h', 'he'): 4,
#          ('he', 'des'): 4,
#          ('fensters', 'liefert'): 3,
#          ('liefert', 'das'): 4,
#          ('das', 'aktuell'): 6,
#          ('aktuell', 'vom'): 6,
#          ('vom', 'drawwindow'): 6,
#          ('drawwindow', 'angezeigte'): 3,
#          ('angezeigte', 'drawingboard'): 3,
#          ('drawingboard', 'zur'): 3,
#          ('zur', 'ck'): 17,
#          ('ck', '@return'): 8,
#          ('@return', 'das'): 5,
#          ('das', 'aktuelle'): 4,
#          ('aktuelle', 'drawingboard'): 3,
#          ('drawingboard', 'f'): 3,
#          ('gt', 'dem'): 3,
#          ('dem', 'drawwindow'): 3,
#          ('drawwindow', 'ein'): 3,
#          ('neues', 'drawingboard'): 3,
#          ('drawingboard', 'hinzu'): 3,
#          ('hinzu', 'dieses'): 3,
#          ('dieses', 'wird'): 3,
#          ('wird', 'nicht'): 3,
#          ('nicht', 'zum'): 3,
#          ('zum', 'aktuellen'): 3,
#          ('aktuellen', 'drawingboard'): 3,
#          ('drawingboard', 'ndert'): 3,
#          ('ndert', 'das'): 3,
#          ('drawwindow', 'gezeigte'): 3,
#          ('gezeigte', 'drawingboard'): 3,
#          ('drawingboard', '@param'): 3,
#          ('index', 'der'): 6,
#          ('der', 'index'): 6,
#          ('index', 'des'): 5,
#          ('des', 'neuen'): 3,
#          ('neuen', 'zu'): 3,
#          ('zu', 'zeigenden'): 3,
#          ('zeigenden', 'drawingboards'): 3,
#          ('drawingboards', 'angefangen'): 3,
#          ('angefangen', 'bei'): 3,
#          ('bei', '0'): 3,
#          ('0', 'status'): 5,
#          ('status', '0'): 10,
#          ('0', 'msg'): 3,
#          ('msg', 'aaa'): 6,
#          ('aaa', 'date'): 3,
#          ('date', 'status'): 3,
#          ('status', 'msg'): 5,
#          ('aaa', 'this'): 3,
#          ('this', 'method'): 44111,
#          ('method', 'was'): 10041,
#          ('was', 'generated'): 9974,
#          ('generated', 'by'): 10384,
#          ('by', 'mybatis'): 9905,
#          ('mybatis', 'generator'): 9905,
#          ('generator', 'this'): 9913,
#          ('method', 'returns'): 6059,
#          ('returns', 'the'): 31662,
#          ('the', 'value'): 31882,
#          ('value', 'of'): 22633,
#          ('of', 'the'): 107738,
#          ('the', 'database'): 11585,
#          ('database', 'column'): 6852,
#          ('column', 'neuedu'): 477,
#          ('neuedu', 'cart'): 84,
#          ('cart', 'id'): 12,
#          ('id', '@return'): 2087,
#          ('@return', 'the'): 59121,
#          ('of', 'neuedu'): 239,
#          ('id', '@mbggenerated'): 872,
#          ('@mbggenerated', 'this'): 1820,
#          ('method', 'sets'): 3578,
#          ('sets', 'the'): 19422,
#          ('id', '@param'): 3162,
#          ('@param', 'id'): 2402,
#          ('id', 'the'): 1433,
#          ('value', 'for'): 6841,
#          ('for', 'neuedu'): 238,
#          ('cart', 'user'): 12,
#          ('user', 'id'): 619,
#          ('@param', 'userid'): 310,
#          ('userid', 'the'): 156,
#          ('cart', 'product'): 12,
#          ('product', 'id'): 96,
#          ('@param', 'productid'): 23,
#          ('productid', 'the'): 13,
#          ('cart', 'quantity'): 12,
#          ('quantity', '@return'): 30,
#          ('quantity', '@mbggenerated'): 40,
#          ('quantity', '@param'): 54,
#          ('@param', 'quantity'): 54,
#          ('quantity', 'the'): 48,
#          ('cart', 'checked'): 12,
#          ('checked', '@return'): 381,
#          ('checked', '@mbggenerated'): 6,
#          ('checked', '@param'): 169,
#          ('@param', 'checked'): 55,
#          ('checked', 'the'): 35,
#          ('cart', 'create'): 14,
#          ('create', 'time'): 585,
#          ('time', '@return'): 825,
#          ('time', '@mbggenerated'): 638,
#          ('time', '@param'): 1036,
#          ('@param', 'createtime'): 187,
#          ('createtime', 'the'): 160,
#          ('cart', 'update'): 14,
#          ('update', 'time'): 570,
#          ('@param', 'updatetime'): 140,
#          ('updatetime', 'the'): 137,
#          ('neuedu', 'category'): 84,
#          ('category', 'id'): 50,
#          ('category', 'parent'): 12,
#          ('parent', 'id'): 121,
#          ('@param', 'parentid'): 42,
#          ('parentid', 'the'): 16,
#          ('category', 'name'): 41,
#          ('name', '@return'): 2137,
#          ('name', '@mbggenerated'): 252,
#          ('name', '@param'): 3753,
#          ('name', 'the'): 2949,
#          ('category', 'status'): 18,
#          ('status', '@return'): 264,
#          ('status', '@mbggenerated'): 132,
#          ('status', '@param'): 264,
#          ('@param', 'status'): 308,
#          ('status', 'the'): 150,
#          ('category', 'sort'): 12,
#          ('sort', 'order'): 125,
#          ('order', '@return'): 201,
#          ('order', '@mbggenerated'): 6,
#          ('order', '@param'): 471,
#          ('@param', 'sortorder'): 23,
#          ('sortorder', 'the'): 5,
#          ('category', 'create'): 14,
#          ('category', 'update'): 14,
#          ('neuedu', 'order'): 300,
#          ('order', 'id'): 61,
#          ('order', 'user'): 12,
#          ('order', 'order'): 38,
#          ('order', 'no'): 43,
#          ('no', '@return'): 60,
#          ('no', '@mbggenerated'): 58,
#          ('no', '@param'): 61,
#          ('@param', 'orderno'): 12,
#          ('orderno', 'the'): 10,
#          ('order', 'shipping'): 13,
#          ('shipping', 'id'): 24,
#          ('@param', 'shippingid'): 3,
#          ('shippingid', 'the'): 3,
#          ('order', 'payment'): 38,
#          ('payment', '@return'): 10,
#          ('payment', '@mbggenerated'): 6,
#          ('payment', '@param'): 4,
#          ('@param', 'payment'): 6,
#          ('payment', 'the'): 4,
#          ('payment', 'type'): 18,
#          ('type', '@return'): 1259,
#          ('type', '@mbggenerated'): 252,
#          ('type', '@param'): 2061,
#          ('@param', 'paymenttype'): 3,
#          ('paymenttype', 'the'): 3,
#          ('order', 'postage'): 12,
#          ('postage', '@return'): 3,
#          ('postage', '@mbggenerated'): 6,
#          ('postage', '@param'): 3,
#          ('@param', 'postage'): 3,
#          ('postage', 'the'): 3,
#          ('order', 'status'): 22,
#          ('payment', 'time'): 12,
#          ('@param', 'paymenttime'): 3,
#          ('paymenttime', 'the'): 3,
#          ('order', 'send'): 12,
#          ('send', 'time'): 27,
#          ('@param', 'sendtime'): 5,
#          ('sendtime', 'the'): 5,
#          ('order', 'end'): 12,
#          ('end', 'time'): 144,
#          ('@param', 'endtime'): 63,
#          ('endtime', 'the'): 24,
#          ('order', 'close'): 12,
#          ('close', 'time'): 16,
#          ('@param', 'closetime'): 3,
#          ('closetime', 'the'): 3,
#          ('order', 'create'): 17,
#          ('order', 'update'): 12,
#          ('order', 'item'): 141,
#          ('item', 'id'): 144,
#          ('item', 'user'): 12,
#          ('item', 'order'): 25,
#          ('item', 'product'): 37,
#          ('product', 'name'): 77,
#          ('@param', 'productname'): 22,
#          ('productname', 'the'): 8,
#          ('product', 'image'): 14,
#          ('image', '@return'): 345,
#          ('image', '@mbggenerated'): 11,
#          ('image', '@param'): 940,
#          ('@param', 'productimage'): 3,
#          ('productimage', 'the'): 3,
#          ('item', 'current'): 12,
#          ('current', 'unit'): 15,
#          ('unit', 'price'): 16,
#          ('price', '@return'): 24,
#          ('price', '@mbggenerated'): 16,
#          ('price', '@param'): 41,
#          ('@param', 'currentunitprice'): 3,
#          ('currentunitprice', 'the'): 3,
#          ('item', 'quantity'): 13,
#          ('item', 'total'): 14,
#          ('total', 'price'): 24,
#          ('@param', 'totalprice'): 4,
#          ('totalprice', 'the'): 4,
#          ('item', 'create'): 19,
#          ('item', 'update'): 21,
#          ('neuedu', 'payinfo'): 96,
#          ('payinfo', 'id'): 12,
#          ('payinfo', 'user'): 12,
#          ('payinfo', 'order'): 12,
#          ('payinfo', 'pay'): 12,
#          ('pay', 'platform'): 12,
#          ('platform', '@return'): 27,
#          ('platform', '@mbggenerated'): 22,
#          ('platform', '@param'): 22,
#          ('@param', 'payplatform'): 3,
#          ('payplatform', 'the'): 3,
#          ('payinfo', 'platform'): 24,
#          ('platform', 'number'): 12,
#          ('number', '@return'): 505,
#          ('number', '@mbggenerated'): 23,
#          ('number', '@param'): 697,
#          ('@param', 'platformnumber'): 3,
#          ('platformnumber', 'the'): 3,
#          ('platform', 'status'): 12,
#          ('@param', 'platformstatus'): 3,
#          ('platformstatus', 'the'): 3,
#          ('payinfo', 'create'): 12,
#          ('payinfo', 'update'): 12,
#          ('neuedu', 'product'): 114,
#          ('product', 'category'): 14,
#          ('@param', 'categoryid'): 10,
#          ('categoryid', 'the'): 6,
#          ('product', 'subtitle'): 12,
#          ('subtitle', '@return'): 9,
#          ('subtitle', '@mbggenerated'): 6,
#          ('subtitle', '@param'): 16,
#          ('@param', 'subtitle'): 10,
#          ('subtitle', 'the'): 5,
#          ('product', 'main'): 10,
#          ('main', 'image'): 19,
#          ('@param', 'mainimage'): 2,
#          ('mainimage', 'the'): 2,
#          ('product', 'price'): 14,
#          ('@param', 'price'): 57,
#          ('price', 'the'): 32,
#          ('product', 'stock'): 8,
#          ('stock', '@return'): 11,
#          ('stock', '@mbggenerated'): 31,
#          ('stock', '@param'): 30,
#          ('@param', 'stock'): 23,
#          ('stock', 'the'): 14,
#          ('product', 'status'): 8,
#          ('product', 'create'): 8,
#          ('product', 'update'): 10,
#          ('product', 'sub'): 8,
#          ('sub', 'images'): 15,
#          ('images', '@return'): 40,
#          ('images', '@mbggenerated'): 4,
#          ('images', '@param'): 87,
#          ('@param', 'subimages'): 2,
#          ('subimages', 'the'): 2,
#          ('product', 'detail'): 18,
#          ('detail', '@return'): 7,
#          ('detail', '@mbggenerated'): 65,
#          ('detail', '@param'): 26,
#          ('@param', 'detail'): 7,
#          ('detail', 'the'): 14,
#          ('neuedu', 'shipping'): 144,
#          ('shipping', 'user'): 12,
#          ('shipping', 'receiver'): 96,
#          ('receiver', 'name'): 12,
#          ('@param', 'receivername'): 3,
#          ('receivername', 'the'): 3,
#          ('receiver', 'phone'): 12,
#          ('phone', '@return'): 109,
#          ('phone', '@mbggenerated'): 42,
#          ('phone', '@param'): 78,
#          ('@param', 'receiverphone'): 3,
#          ('receiverphone', 'the'): 3,
#          ('receiver', 'mobile'): 12,
#          ('mobile', '@return'): 19,
#          ('mobile', '@mbggenerated'): 6,
#          ('mobile', '@param'): 16,
#          ('@param', 'receivermobile'): 3,
#          ('receivermobile', 'the'): 3,
#          ('receiver', 'province'): 12,
#          ('province', '@return'): 14,
#          ('province', '@mbggenerated'): 24,
#          ('province', '@param'): 16,
#          ('@param', 'receiverprovince'): 3,
#          ('receiverprovince', 'the'): 3,
#          ('receiver', 'city'): 12,
#          ('city', '@return'): 25,
#          ('city', '@mbggenerated'): 6,
#          ('city', '@param'): 27,
#          ('@param', 'receivercity'): 3,
#          ('receivercity', 'the'): 3,
#          ('receiver', 'district'): 12,
#          ('district', '@return'): 4,
#          ('district', '@mbggenerated'): 8,
#          ('district', '@param'): 4,
#          ('@param', 'receiverdistrict'): 3,
#          ('receiverdistrict', 'the'): 3,
#          ('receiver', 'address'): 12,
#          ('address', '@return'): 277,
#          ('address', '@mbggenerated'): 72,
#          ('address', '@param'): 443,
#          ('@param', 'receiveraddress'): 3,
#          ('receiveraddress', 'the'): 3,
#          ('receiver', 'zip'): 12,
#          ('zip', '@return'): 4,
#          ('zip', '@mbggenerated'): 6,
#          ('zip', '@param'): 26,
#          ('@param', 'receiverzip'): 3,
#          ('receiverzip', 'the'): 3,
#          ('shipping', 'create'): 12,
#          ('shipping', 'update'): 12,
#          ('neuedu', 'user'): 132,
#          ('user', 'username'): 29,
#          ('username', '@return'): 104,
#          ('username', '@mbggenerated'): 6,
#          ('username', '@param'): 249,
#          ('@param', 'username'): 510,
#          ('username', 'the'): 168,
#          ('user', 'password'): 64,
#          ('password', '@return'): 239,
#          ('password', '@mbggenerated'): 8,
#          ('password', '@param'): 296,
#          ('@param', 'password'): 505,
#          ('password', 'the'): 214,
#          ('user', 'email'): 48,
#          ('email', '@return'): 73,
#          ('email', '@mbggenerated'): 26,
#          ('email', '@param'): 177,
#          ('@param', 'email'): 205,
#          ('email', 'the'): 75,
#          ('user', 'phone'): 12,
#          ('@param', 'phone'): 79,
#          ('phone', 'the'): 29,
#          ('user', 'question'): 12,
#          ('question', '@return'): 91,
#          ('question', '@mbggenerated'): 6,
#          ('question', '@param'): 99,
#          ('@param', 'question'): 6,
#          ('question', 'the'): 5,
#          ('user', 'answer'): 18,
#          ('answer', '@return'): 9,
#          ('answer', '@mbggenerated'): 6,
#          ('answer', '@param'): 28,
#          ('@param', 'answer'): 7,
#          ('answer', 'the'): 21,
#          ('user', 'role'): 75,
#          ('role', '@return'): 45,
#          ('role', '@mbggenerated'): 70,
#          ('role', '@param'): 45,
#          ('@param', 'role'): 100,
#          ('role', 'the'): 65,
#          ('user', 'create'): 37,
#          ('user', 'update'): 36,
#          ('user', 'ip'): 14,
#          ('ip', '@return'): 52,
#          ('ip', '@mbggenerated'): 20,
#          ('ip', '@param'): 91,
#          ('@param', 'ip'): 74,
#          ('ip', 'the'): 33,
#          ('@mbggenerated', 'ftp'): 2,
#          ('ftp', '@param'): 27,
#          ('@param', 'remotepath'): 8,
#          ('remotepath', 'ftp'): 2,
#          ('@param', 'filelist'): 21,
#          ('filelist', '@param'): 7,
#          ('@param', 'ftputils'): 2,
#          ('ftputils', '@return'): 2,
#          ('@return', 'memberscoreassessor'): 2,
#          ('memberscoreassessor', 'will'): 3,
#          ('will', 'assess'): 3,
#          ('assess', 'risk'): 3,
#          ('risk', 'score'): 3,
#          ('score', 'for'): 57,
#          ('for', 'each'): 2149,
#          ('each', 'member'): 10,
#          ('member', '@param'): 39,
#          ('@param', 'memberdata'): 15,
#          ('memberdata', '@return'): 12,
#          ('@return', 'this'): 5063,
#          ('this', 'addscoreformembers'): 2,
#          ('addscoreformembers', 'will'): 2,
#          ('will', 'assign'): 8,
#          ('assign', 'penalty'): 2,
#          ('penalty', 'points'): 2,
#          ('points', 'to'): 383,
#          ('to', 'members'): 2,
#          ('members', 'based'): 2,
#          ('based', 'on'): 3993,
#          ('on', 'their'): 107,
#          ('their', 'age'): 4,
#          ('age', 'blood'): 2,
#          ('blood', 'pressure'): 2,
#          ('pressure', 'bmi'): 2,
#          ('bmi', 'and'): 2,
#          ('and', 'disease'): 2,
#          ('disease', 'in'): 2,
#          ('in', 'family'): 6,
#          ('family', 'if'): 3,
#          ('if', 'any'): 3578,
#          ('any', '@'): 2,
#          ('@', 'this'): 3,
#          ('this', 'is'): 10668,
#          ('is', 'a'): 9709,
#          ('a', 'required'): 96,
#          ('required', 'default'): 13,
#          ('default', 'constructor'): 1529,
#          ('constructor', 'to'): 389,
#          ('to', 'handle'): 989,
#          ('handle', 'the'): 674,
#          ('the', 'xml'): 765,
#          ('xml', 'serialization'): 8,
#          ('serialization', 'constructor'): 7,
#          ('constructor', 'used'): 132,
#          ('used', 'to'): 8848,
#          ('to', 'set'): 9037,
#          ('set', 'the'): 10900,
#          ('the', 'values'): 2260,
#          ('values', '@param'): 858,
#          ('@param', 'fname'): 150,
#          ('fname', '@param'): 23,
#          ('@param', 'lname'): 23,
#          ('lname', '@param'): 14,
#          ('@param', 'age'): 14,
#          ('age', '@param'): 14,
#          ('height', '@param'): 494,
#          ('@param', 'weight'): 81,
#          ('weight', '@param'): 53,
#          ('@param', 'bpsystolic'): 3,
#          ('bpsystolic', '@param'): 3,
#          ('@param', 'bpdiastolic'): 3,
#          ('bpdiastolic', '@param'): 3,
#          ('@param', 'cancer'): 3,
#          ('cancer', '@param'): 3,
#          ('@param', 'diabetes'): 3,
#          ('diabetes', '@param'): 3,
#          ('@param', 'alzheimers'): 3,
#          ('alzheimers', 'getters'): 3,
#          ('getters', 'and'): 81,
#          ('and', 'setters'): 72,
#          ('setters', 'used'): 4,
#          ('to', 'access'): 761,
#          ('access', 'data'): 8,
#          ('data', '@return'): 859,
#          ('@return', 'insurance'): 3,
#          ('insurance', 'score'): 3,
#          ('score', 'constructor'): 4,
#          ('constructor', 'that'): 383,
#          ('that', 'will'): 3577,
#          ('will', 'calculate'): 16,
#          ('calculate', 'the'): 647,
#          ('the', 'risklevel'): 3,
#          ('risklevel', 'within'): 3,
#          ('within', 'itself'): 3,
#          ('itself', '@param'): 182,
#          ('@param', 'score'): 45,
#          ('score', 'default'): 3,
#          ('constructor', 'in'): 30,
#          ('in', 'case'): 1984,
#          ('case', 'we'): 177,
#          ('we', 'need'): 630,
#          ('need', 'to'): 2564,
#          ('to', 'serialize'): 116,
#          ('serialize', 'in'): 3,
#          ('in', 'xml'): 87,
#          ('xml', 'tostring'): 3,
#          ('tostring', 'function'): 4,
#          ('function', 'will'): 345,
#          ('will', 'print'): 44,
#          ('print', 'the'): 266,
#          ('the', 'insurance'): 3,
#          ('insurance', 'details'): 3,
#          ('details', 'with'): 7,
#          ('with', 'risk'): 3,
#          ('risk', 'assessment'): 9,
#          ('assessment', 'of'): 5,
#          ('of', 'members'): 38,
#          ('members', 'in'): 14,
#          ('in', 'a'): 6246,
#          ('a', 'formatted'): 117,
#          ('formatted', 'way'): 3,
#          ('way', 'writeriskinformation'): 3,
#          ('writeriskinformation', 'function'): 3,
#          ('will', 'write'): 62,
#          ('write', 'the'): 592,
#          ('the', 'risk'): 25,
#          ('assessment', 'information'): 3,
#          ('information', 'for'): 365,
#          ('@param', 'assess'): 3,
#          ('assess', 'writememberstojson'): 3,
#          ('writememberstojson', 'function'): 3,
#          ('will', 'allow'): 123,
#          ('allow', 'the'): 452,
#          ('the', 'member'): 81,
#          ('member', 'risk'): 3,
#          ('assessment', 'to'): 3,
#          ('to', 'be'): 24403,
#          ('be', 'stored'): 489,
#          ('stored', 'in'): 1423,
#          ('a', 'json'): 240,
#          ('json', 'file'): 28,
#          ('file', 'format'): 95,
#          ('format', '@param'): 523,
#          ('@param', 'assessment'): 3,
#          ('assessment', '@return'): 3,
#          ('this', 'function'): 2237,
#          ('will', 'read'): 81,
#          ('read', 'the'): 804,
#          ('the', 'tab'): 736,
#          ('tab', 'delimited'): 6,
#          ('delimited', 'test'): 3,
#          ('test', 'file'): 36,
#          ('file', 'and'): 534,
#          ('and', 'store'): 165,
#          ('store', 'into'): 11,
#          ('into', 'an'): 833,
#          ('an', 'arraylist'): 266,
#          ('arraylist', '@param'): 32,
#          ('fname', '@return'): 10,
#          ('@return', 'readdatafrombinary'): 3,
#          ('readdatafrombinary', 'function'): 3,
#          ('read', 'back'): 59,
#          ('back', 'data'): 7,
#          ('data', 'from'): 1228,
#          ('from', 'stored'): 9,
#          ('stored', 'binary'): 3,
#          ('binary', 'file'): 54,
#          ('file', 'it'): 61,
#          ('it', 'will'): 2888,
#          ('will', 'be'): 25221,
#          ('be', 'used'): 9227,
#          ('to', 'count'): 69,
#          ('count', 'number'): 40,
#          ('number', 'of'): 19276,
#          ('members', 'read'): 5,
#          ('read', 'stored'): 3,
#          ('stored', 'from'): 5,
#          ('from', 'binary'): 9,
#          ('binary', '@param'): 13,
#          ('@return', 'readmemberdatafromxml'): 3,
#          ('readmemberdatafromxml', 'function'): 3,
#          ('stored', 'xml'): 3,
#          ('xml', 'file'): 241,
#          ('count', 'read'): 4,
#          ('read', 'number'): 4,
#          ('members', 'from'): 10,
#          ('from', 'the'): 20233,
#          ('the', 'file'): 5430,
#          ('file', '@param'): 2128,
#          ('print', 'members'): 3,
#          ('from', 'file'): 92,
#          ('file', 'to'): 1280,
#          ('to', 'the'): 43562,
#          ('the', 'screen'): 1431,
#          ('screen', 'with'): 34,
#          ('with', 'formatting'): 7,
#          ('formatting', '@param'): 125,
#          ('memberdata', 'this'): 3,
#          ('will', 'save'): 46,
#          ('save', 'member'): 6,
#          ('member', 'data'): 6,
#          ('from', 'arraylist'): 8,
#          ('arraylist', 'to'): 11,
#          ('the', 'text'): 3944,
#          ('text', 'file'): 166,
#          ('file', 'in'): 465,
#          ('in', 'tab'): 4,
#          ('delimited', 'file'): 4,
#          ('arraylist', 'into'): 10,
#          ('into', 'binaryfile'): 3,
#          ('binaryfile', 'format'): 3,
#          ('save', 'members'): 3,
#          ('in', 'array'): 141,
#          ('array', 'list'): 61,
#          ('list', 'in'): 169,
#          ('a', 'xml'): 39,
#          ('@return', 'welcome'): 5,
#          ('welcome', 'function'): 3,
#          ('the', 'greeting'): 3,
#          ('greeting', 'message'): 3,
#          ('message', 'to'): 2221,
#          ('screen', 'this'): 87,
#          ('this', 'show'): 5,
#          ('show', 'menu'): 5,
#          ('menu', 'function'): 3,
#          ('print', 'list'): 3,
#          ('list', 'of'): 9678,
#          ('of', 'options'): 55,
#          ('options', 'that'): 48,
#          ('that', 'user'): 62,
#          ('user', 'can'): 291,
#          ('can', 'choose'): 47,
#          ('choose', 'from'): 36,
#          ('from', 'this'): 2750,
#          ('this', 'addmember'): 2,
#          ('addmember', 'function'): 2,
#          ('the', 'user'): 7464,
#          ('user', 'to'): 669,
#          ('to', 'enter'): 105,
#          ('enter', 'a'): 91,
#          ('a', 'new'): 22091,
#          ('new', 'member'): 13,
#          ('member', 'begin'): 2,
#          ('begin', 'main'): 2,
#          ('main', 'function'): 49,
#          ('function', 'this'): 53,
#          ('method', 'geneseegame'): 6,
#          ('geneseegame', 'uses'): 6,
#          ('uses', 'the'): 1272,
#          ('the', 'the'): 761,
#          ('the', 'above'): 296,
#          ('above', 'final'): 6,
#          ('final', 'values'): 9,
#          ('values', 'arraylists'): 6,
#          ('arraylists', 'when'): 6,
#          ('when', 'calling'): 176,
#          ('calling', 'the'): 391,
#          ('the', 'method'): 3746,
#          ('method', 'playgame'): 6,
#          ('playgame', 'hole'): 6,
#          ('hole', 'g'): 2,
#          ('g', 'yardage'): 2,
#          ('yardage', 'g'): 2,
#          ('g', 'par'): 2,
#          ('par', 'g'): 2,
#          ('g', 'from'): 32,
#          ('the', 'class'): 3406,
#          ('class', 'playgame'): 6,
#          ('playgame', 'this'): 6,
#          ('hole', 'o'): 2,
#          ('o', 'yardage'): 2,
#          ('yardage', 'o'): 2,
#          ('o', 'par'): 2,
#          ('par', 'o'): 2,
#          ('o', 'from'): 5,
#          ('hole', 'm'): 2,
#          ('m', 'yardage'): 2,
#          ('yardage', 'm'): 2,
#          ('m', 'par'): 2,
#          ('par', 'm'): 2,
#          ('m', 'from'): 42,
#          ('method', 'has'): 333,
#          ('has', 'instances'): 2,
#          ('instances', 'of'): 595,
#          ('of', 'type'): 1146,
#          ('type', 'course'): 2,
#          ('course', 'and'): 7,
#          ('and', 'asks'): 5,
#          ('asks', 'the'): 61,
#          ('user', 'for'): 153,
#          ('for', 'course'): 2,
#          ('course', 'number'): 4,
#          ('number', 'and'): 221,
#          ('and', 'based'): 8,
#          ('on', 'the'): 13824,
#          ('user', 'preferences'): 37,
#          ('preferences', 'it'): 2,
#          ('it', 'calls'): 56,
#          ('calls', 'for'): 37,
#          ('for', 'the'): 27363,
#          ('the', 'type'): 4005,
#          ('type', 'of'): 3902,
#          ('of', 'course'): 55,
#          ('course', 'the'): 11,
#          ('user', 'chose'): 7,
#          ('chose', 'to'): 3,
#          ('to', 'play'): 225,
#          ('play', 'if'): 4,
#          ('if', 'the'): 45807,
#          ('user', 'chooses'): 10,
#          ('chooses', 'a'): 26,
#          ('a', 'course'): 10,
#          ('number', 'which'): 132,
#          ('which', 'is'): 3012,
#          ('is', 'not'): 13019,
#          ('not', 'in'): 849,
#          ('in', 'the'): 40113,
#          ('the', 'list'): 7156,
#          ('list', 'the'): 422,
#          ('the', 'program'): 824,
#          ('program', 'will'): 39,
#          ('will', 'quit'): 3,
#          ('quit', 'executing'): 2,
#          ('executing', 'a'): 13,
#          ('a', 'print'): 33,
#          ('print', 'line'): 2,
#          ('line', 'statement'): 2,
#          ('statement', 'with'): 27,
#          ('with', 'information'): 105,
#          ('information', 'a'): 9,
#          ('a', 'ade'): 24,
#          ('ade', 'un'): 7,
#          ('un', 'listener'): 5,
#          ('listener', 'al'): 4,
#          ('al', 'modelo'): 4,
#          ('modelo', 'a'): 2,
#          ('modelo', 'si'): 2,
#          ('si', 'pinchamos'): 2,
#          ('pinchamos', 'en'): 2,
#          ('en', 'ok'): 2,
#          ('ok', 'este'): 2,
#          ('este', 'm'): 12,
#          ('m', 'todo'): 105,
#          ('todo', 'est'): 3,
#          ('est', 'llamado'): 2,
#          ('llamado', 'para'): 2,
#          ('para', 'empezar'): 2,
#          ('empezar', 'a'): 2,
#          ('a', 'buscar'): 20,
#          ('buscar', 'el'): 7,
#          ('el', 'camino'): 14,
#          ('camino', '@param'): 6,
#          ('@param', 'origin'): 124,
#          ('origin', '@param'): 119,
#          ('@param', 'destination'): 143,
#          ('destination', '@throws'): 10,
#          ('@throws', 'exception'): 3357,
#          ('exception', 'devuelve'): 2,
#          ('devuelve', 'el'): 37,
#          ('camino', 'm'): 6,
#          ('m', 's'): 65,
#          ('s', 'corto'): 6,
#          ('corto', 'entre'): 4,
#          ('entre', 'si'): 4,
#          ('si', 'y'): 4,
#          ('y', 'sf'): 4,
#          ('sf', 'devuelve'): 2,
#          ('sf', 'encuentra'): 2,
#          ('encuentra', 'recursivamente'): 2,
#          ('recursivamente', 'el'): 2,
#          ('el', 'mejor'): 2,
#          ('mejor', 'camino'): 2,
#          ('camino', 'con'): 2,
#          ('con', 'el'): 79,
#          ('el', 'algo'): 2,
#          ('algo', 'a'): 3,
#          ('a', 'almacena'): 2,
#          ('almacena', 'en'): 10,
#          ('en', 'los'): 11,
#          ('los', 'atributos'): 8,
#          ('atributos', 'almacena'): 2,
#          ('en', 'waytohere'): 2,
#          ('waytohere', 'de'): 2,
#          ('de', 'cada'): 9,
#          ('cada', 'nodo'): 2,
#          ('nodo', 'el'): 2,
#          ('corto', 'para'): 2,
#          ('para', 'ir'): 2,
#          ('ir', 'al'): 2,
#          ('al', 'nodo'): 2,
#          ('nodo', 'desde'): 2,
#          ('desde', 'si'): 2,
#          ('si', '@param'): 2,
#          ('@param', 'padre'): 2,
#          ('padre', 'pone'): 2,
#          ('pone', 'en'): 7,
#          ('en', 'la'): 186,
#          ('la', 'lista'): 61,
#          ('lista', 'abierta'): 6,
#          ('abierta', 'todos'): 2,
#          ('todos', 'las'): 2,
#          ('las', 'estaciones'): 10,
#          ('estaciones', 'de'): 4,
#          ('de', 's'): 2,
#          ('s', 'que'): 5,
#          ('que', 'no'): 14,
#          ('no', 'ya'): 2,
#          ('ya', 'est'): 3,
#          ('est', 'n'): 11,
#          ('n', 'en'): 13,
#          ('abierta', 'ni'): 2,
#          ('ni', 'en'): 2,
#          ('lista', 'cerrada'): 2,
#          ('cerrada', '@param'): 2,
#          ('@param', 's'): 1636,
#          ('s', 'reordena'): 2,
#          ('reordena', 'la'): 2,
#          ('lista', 'de'): 109,
#          ('de', 'estaci'): 2,
#          ('estaci', 'n'): 10,
#          ('n', 'por'): 3,
#          ('por', 'm'): 2,
#          ('m', 'nimo'): 12,
#          ('nimo', 'de'): 2,
#          ('de', 'f'): 2,
#          ('f', 'almacena'): 2,
#          ('almacena', 'la'): 2,
#          ('la', 'nueva'): 11,
#          ('nueva', 'lista'): 2,
#          ('lista', 'en'): 2,
#          ('abierta', 'openedlist'): 2,
#          ('openedlist', '@param'): 2,
#          ('@param', 'stationclone'): 2,
#          ('stationclone', 'devuelve'): 2,
#          ('el', 'id'): 18,
#          ('id', 'de'): 31,
#          ('de', 'la'): 1087,
#          ('la', 'estaci'): 6,
#          ('n', 'que'): 27,
#          ('que', 'tiene'): 16,
#          ('tiene', 'el'): 7,
#          ('el', 'f'): 2,
#          ('f', 'm'): 11,
#          ('nimo', 'en'): 2,
#          ('en', 'toda'): 2,
#          ('toda', 'la'): 5,
#          ('lista', '@param'): 4,
#          ('s', '@return'): 222,
#          ('@return', 'busca'): 2,
#          ('busca', 'los'): 8,
#          ('los', 'objetos'): 6,
#          ('objetos', 'estaciones'): 4,
#          ('estaciones', 'correspondientes'): 4,
#          ('correspondientes', 'al'): 4,
#          ('al', 'origen'): 4,
#          ('origen', 'y'): 5,
#          ('y', 'destino'): 4,
#          ('destino', 'y'): 4,
#          ('y', 'llama'): 5,
#          ('llama', 'al'): 6,
#          ('al', 'algoritmo'): 4,
#          ('algoritmo', 'para'): 4,
#          ('para', 'encontrar'): 5,
#          ('encontrar', 'el'): 5,
#          ('destination', 'busca'): 2,
#          ('destination', 'limpia'): 2,
#          ('limpia', 'todas'): 2,
#          ('todas', 'las'): 7,
#          ('de', 'los'): 109,
#          ('los', 'posibles'): 9,
#          ('posibles', 'g'): 2,
#          ('g', 'h'): 30,
#          ('h', 'f'): 6,
#          ('f', 'y'): 68,
#          ('y', 'caminos'): 2,
#          ('caminos', 'registrados'): 2,
#          ('registrados', 'a'): 2,
#          ('ade', 'listener'): 2,
#          ('listener', '@param'): 659,
#          ('@param', 'ecouteur'): 2,
#          ('ecouteur', 'lee'): 2,
#          ('lee', 'el'): 8,
#          ('el', 'fichero'): 9,
#          ('fichero', 'y'): 4,
#          ('y', 'rellena'): 4,
#          ('rellena', 'distances'): 6,
#          ('distances', 'y'): 4,
#          ('y', 'stations'): 4,
#          ('stations', 'lee'): 2,
#          ('stations', 'rellena'): 2,
#          ('rellena', 'station'): 2,
#          ('station', 'con'): 2,
#          ('con', 'todas'): 4,
#          ('todas', 'la'): 2,
#          ('la', 'estaciones'): 2,
#          ('estaciones', 'encontradas'): 2,
#          ('encontradas', 'en'): 2,
#          ('en', 'el'): 389,
#          ('fichero', '@param'): 2,
#          ('s', 'rellena'): 2,
#          ('rellena', 'las'): 2,
#          ('las', 'distancias'): 2,
#          ...})

# %%
# using the bow's, creates 3 new pandas dataframes and puts the frequencies in descending order
word_freq = pd.DataFrame(bow.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
word_pairs = pd.DataFrame(bow2.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
trigrams = pd.DataFrame(bow3.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)

# %%
# creates bargraphs that show occurances of certain words, pairs, and trigrams
fig, axes = plt.subplots(3,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=word_freq.head(30)).set_title('Includes Stopwords')
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=word_pairs.head(30))
sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=trigrams.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='trigrams'>
